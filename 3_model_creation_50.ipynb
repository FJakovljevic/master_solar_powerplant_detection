# %% [markdown]
# # Imports

# %%
# %pip install segmentation_models -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 5.7 MB/s eta 0:00:00

# %%
# !unzip /content/data.zip

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator

os.environ["SM_FRAMEWORK"] = "tf.keras"
from tensorflow import keras
import segmentation_models as sm

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Segmentation Models: using `tf.keras` framework.
# Mounted at /content/drive

# %%
# !cp '/content/drive/My Drive/Colab Notebooks/data.zip' /content

# %%
# !unzip -q /content/data.zip

# %% [markdown]
# # Constants

# %%
seed = 13
batch_size = 16
target_size = (256, 256)

DATASET_FOLDER = f'/content/data'
#DATASET_FOLDER = f'/content/drive/My Drive/Colab Notebooks/data'
train_img_path = f'{DATASET_FOLDER}/train_images/img'
train_masks_path = f'{DATASET_FOLDER}/train_masks/img'
val_img_path = f'{DATASET_FOLDER}/val_images/img'
val_masks_path = f'{DATASET_FOLDER}/val_masks/img'

num_train_imgs = len(os.listdir(train_img_path))
num_val_images = len(os.listdir(val_img_path))

steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

backbone_network = 'resnet50'
model_checkpoint_path = "/content/drive/My Drive/Colab Notebooks/model_checkpoints/model-{epoch:02d}-{val_iou_score:.4f}" + f"unet_{backbone_network}.hdf5"

# %% [markdown]
# # Helper functions

# %%
def image_mask_generator(image_data_generator, mask_data_generator):
    train_generator = zip(image_data_generator, mask_data_generator)
    for (img, mask) in train_generator:
        yield (img/255, to_categorical(mask/255))

def create_generator_pair(img_path, mask_path):
    image_data_generator = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, fill_mode='reflect')
    image_data_generator = image_data_generator.flow_from_directory(img_path[:-4],
                                                                    class_mode=None,
                                                                    batch_size=batch_size,
                                                                    target_size=target_size,
                                                                    seed=seed)

    mask_data_generator = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, fill_mode='reflect')
    mask_data_generator = mask_data_generator.flow_from_directory(mask_path[:-4],
                                                                  class_mode=None,
                                                                  color_mode='grayscale',
                                                                  batch_size=batch_size,
                                                                  target_size=target_size,
                                                                  seed=seed)

    return image_data_generator, mask_data_generator

def display_images(img_list):
    f, axarr = plt.subplots(1, len(img_list), figsize=(13,13))
    for x, img in enumerate(img_list):
        axarr[x].imshow(img)
    plt.show()

# %% [markdown]
# # Creation of data generator and sanity check

# %%
train_generator = image_mask_generator(*create_generator_pair(train_img_path, train_masks_path))
val_generator = image_mask_generator(*create_generator_pair(val_img_path, val_masks_path))
# Out:
# Found 4306 images belonging to 1 classes.
# Found 4306 images belonging to 1 classes.
# Found 1054 images belonging to 1 classes.
# Found 1054 images belonging to 1 classes.

# %% [markdown]
# ### Model creation

# %%
model = sm.Unet(backbone_network, input_shape=(256,256,3), classes=2, activation='softmax')
model.compile(optimizer='adam', loss=sm.losses.categorical_focal_jaccard_loss, metrics=[sm.metrics.iou_score])
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet50_imagenet_1000_no_top.h5
# 94592056/94592056 [==============================] - 1s 0us/step

# %% [markdown]
# ### Model training

# %%
checkpoint = ModelCheckpoint(model_checkpoint_path, monitor='val_iou_score', verbose=2, save_best_only=True, mode='max')

history = model.fit(train_generator, epochs=100, steps_per_epoch=steps_per_epoch, verbose=2,
                    validation_data=val_generator, validation_steps=val_steps_per_epoch, callbacks=[checkpoint])
# Out:
# Epoch 1/100
#
# Epoch 1: val_iou_score improved from -inf to 0.45562, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-01-0.4556unet_resnet50.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 - 169s - loss: 0.2544 - iou_score: 0.7653 - val_loss: 0.6404 - val_iou_score: 0.4556 - 169s/epoch - 628ms/step
# Epoch 2/100
#
# Epoch 2: val_iou_score improved from 0.45562 to 0.45565, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-02-0.4557unet_resnet50.hdf5
# 269/269 - 121s - loss: 0.2004 - iou_score: 0.8181 - val_loss: 0.6252 - val_iou_score: 0.4557 - 121s/epoch - 448ms/step
# Epoch 3/100
#
# Epoch 3: val_iou_score improved from 0.45565 to 0.46041, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-03-0.4604unet_resnet50.hdf5
# 269/269 - 116s - loss: 0.1949 - iou_score: 0.8237 - val_loss: 0.6368 - val_iou_score: 0.4604 - 116s/epoch - 430ms/step
# Epoch 4/100
#
# Epoch 4: val_iou_score improved from 0.46041 to 0.72810, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-04-0.7281unet_resnet50.hdf5
# 269/269 - 114s - loss: 0.1821 - iou_score: 0.8351 - val_loss: 0.3020 - val_iou_score: 0.7281 - 114s/epoch - 425ms/step
# Epoch 5/100
#
# Epoch 5: val_iou_score improved from 0.72810 to 0.84068, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-05-0.8407unet_resnet50.hdf5
# 269/269 - 113s - loss: 0.1763 - iou_score: 0.8407 - val_loss: 0.1777 - val_iou_score: 0.8407 - 113s/epoch - 421ms/step
# Epoch 6/100
#
# Epoch 6: val_iou_score did not improve from 0.84068
# 269/269 - 112s - loss: 0.1806 - iou_score: 0.8362 - val_loss: 0.1961 - val_iou_score: 0.8255 - 112s/epoch - 415ms/step
# Epoch 7/100
#
# Epoch 7: val_iou_score did not improve from 0.84068
# 269/269 - 111s - loss: 0.1744 - iou_score: 0.8426 - val_loss: 0.2499 - val_iou_score: 0.7722 - 111s/epoch - 414ms/step
# Epoch 8/100
#
# Epoch 8: val_iou_score did not improve from 0.84068
# 269/269 - 109s - loss: 0.1654 - iou_score: 0.8506 - val_loss: 0.6232 - val_iou_score: 0.5285 - 109s/epoch - 407ms/step
# Epoch 9/100
#
# Epoch 9: val_iou_score did not improve from 0.84068
# 269/269 - 109s - loss: 0.1650 - iou_score: 0.8502 - val_loss: 0.1995 - val_iou_score: 0.8223 - 109s/epoch - 406ms/step
# Epoch 10/100
#
# Epoch 10: val_iou_score improved from 0.84068 to 0.85014, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-10-0.8501unet_resnet50.hdf5
# 269/269 - 113s - loss: 0.1631 - iou_score: 0.8526 - val_loss: 0.1668 - val_iou_score: 0.8501 - 113s/epoch - 421ms/step
# Epoch 11/100
#
# Epoch 11: val_iou_score improved from 0.85014 to 0.85296, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-11-0.8530unet_resnet50.hdf5
# 269/269 - 117s - loss: 0.1667 - iou_score: 0.8492 - val_loss: 0.1629 - val_iou_score: 0.8530 - 117s/epoch - 435ms/step
# Epoch 12/100
#
# Epoch 12: val_iou_score did not improve from 0.85296
# 269/269 - 108s - loss: 0.1607 - iou_score: 0.8548 - val_loss: 0.1723 - val_iou_score: 0.8441 - 108s/epoch - 403ms/step
# Epoch 13/100
#
# Epoch 13: val_iou_score did not improve from 0.85296
# 269/269 - 109s - loss: 0.1581 - iou_score: 0.8568 - val_loss: 0.2476 - val_iou_score: 0.7768 - 109s/epoch - 404ms/step
# Epoch 14/100
#
# Epoch 14: val_iou_score did not improve from 0.85296
# 269/269 - 111s - loss: 0.1593 - iou_score: 0.8556 - val_loss: 0.1780 - val_iou_score: 0.8422 - 111s/epoch - 414ms/step
# Epoch 15/100
#
# Epoch 15: val_iou_score did not improve from 0.85296
# 269/269 - 111s - loss: 0.1558 - iou_score: 0.8591 - val_loss: 0.1716 - val_iou_score: 0.8451 - 111s/epoch - 414ms/step
# Epoch 16/100
#
# Epoch 16: val_iou_score improved from 0.85296 to 0.85708, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-16-0.8571unet_resnet50.hdf5
# 269/269 - 113s - loss: 0.1555 - iou_score: 0.8588 - val_loss: 0.1597 - val_iou_score: 0.8571 - 113s/epoch - 422ms/step
# Epoch 17/100
#
# Epoch 17: val_iou_score improved from 0.85708 to 0.86330, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-17-0.8633unet_resnet50.hdf5
# 269/269 - 111s - loss: 0.1554 - iou_score: 0.8593 - val_loss: 0.1509 - val_iou_score: 0.8633 - 111s/epoch - 413ms/step
# Epoch 18/100
#
# Epoch 18: val_iou_score did not improve from 0.86330
# 269/269 - 111s - loss: 0.1571 - iou_score: 0.8574 - val_loss: 0.1710 - val_iou_score: 0.8456 - 111s/epoch - 414ms/step
# Epoch 19/100
#
# Epoch 19: val_iou_score did not improve from 0.86330
# 269/269 - 109s - loss: 0.1512 - iou_score: 0.8631 - val_loss: 0.1497 - val_iou_score: 0.8628 - 109s/epoch - 405ms/step
# Epoch 20/100
#
# Epoch 20: val_iou_score did not improve from 0.86330
# 269/269 - 109s - loss: 0.1513 - iou_score: 0.8632 - val_loss: 0.1809 - val_iou_score: 0.8372 - 109s/epoch - 406ms/step
# Epoch 21/100
#
# Epoch 21: val_iou_score did not improve from 0.86330
# 269/269 - 110s - loss: 0.1505 - iou_score: 0.8639 - val_loss: 0.1576 - val_iou_score: 0.8566 - 110s/epoch - 407ms/step
# Epoch 22/100
#
# Epoch 22: val_iou_score improved from 0.86330 to 0.86610, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-22-0.8661unet_resnet50.hdf5
# 269/269 - 113s - loss: 0.1503 - iou_score: 0.8635 - val_loss: 0.1466 - val_iou_score: 0.8661 - 113s/epoch - 421ms/step
# Epoch 23/100
#
# Epoch 23: val_iou_score did not improve from 0.86610
# 269/269 - 112s - loss: 0.1629 - iou_score: 0.8516 - val_loss: 0.1667 - val_iou_score: 0.8506 - 112s/epoch - 415ms/step
# Epoch 24/100
#
# Epoch 24: val_iou_score did not improve from 0.86610
# 269/269 - 109s - loss: 0.1539 - iou_score: 0.8602 - val_loss: 0.1715 - val_iou_score: 0.8445 - 109s/epoch - 407ms/step
# Epoch 25/100
#
# Epoch 25: val_iou_score did not improve from 0.86610
# 269/269 - 111s - loss: 0.1474 - iou_score: 0.8658 - val_loss: 0.1521 - val_iou_score: 0.8628 - 111s/epoch - 414ms/step
# Epoch 26/100
#
# Epoch 26: val_iou_score improved from 0.86610 to 0.86842, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-26-0.8684unet_resnet50.hdf5
# 269/269 - 114s - loss: 0.1440 - iou_score: 0.8692 - val_loss: 0.1442 - val_iou_score: 0.8684 - 114s/epoch - 424ms/step
# Epoch 27/100
#
# Epoch 27: val_iou_score improved from 0.86842 to 0.87142, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-27-0.8714unet_resnet50.hdf5
# 269/269 - 115s - loss: 0.1438 - iou_score: 0.8699 - val_loss: 0.1432 - val_iou_score: 0.8714 - 115s/epoch - 427ms/step
# Epoch 28/100
#
# Epoch 28: val_iou_score did not improve from 0.87142
# 269/269 - 111s - loss: 0.1460 - iou_score: 0.8678 - val_loss: 0.1460 - val_iou_score: 0.8677 - 111s/epoch - 414ms/step
# Epoch 29/100
#
# Epoch 29: val_iou_score did not improve from 0.87142
# 269/269 - 108s - loss: 0.1430 - iou_score: 0.8704 - val_loss: 0.1585 - val_iou_score: 0.8569 - 108s/epoch - 401ms/step
# Epoch 30/100
#
# Epoch 30: val_iou_score did not improve from 0.87142
# 269/269 - 111s - loss: 0.1491 - iou_score: 0.8641 - val_loss: 0.1482 - val_iou_score: 0.8653 - 111s/epoch - 413ms/step
# Epoch 31/100
#
# Epoch 31: val_iou_score did not improve from 0.87142
# 269/269 - 111s - loss: 0.1444 - iou_score: 0.8692 - val_loss: 0.1428 - val_iou_score: 0.8709 - 111s/epoch - 413ms/step
# Epoch 32/100
#
# Epoch 32: val_iou_score did not improve from 0.87142
# 269/269 - 111s - loss: 0.1418 - iou_score: 0.8713 - val_loss: 0.1433 - val_iou_score: 0.8694 - 111s/epoch - 413ms/step
# Epoch 33/100
#
# Epoch 33: val_iou_score did not improve from 0.87142
# 269/269 - 111s - loss: 0.1429 - iou_score: 0.8705 - val_loss: 0.1408 - val_iou_score: 0.8710 - 111s/epoch - 414ms/step
# Epoch 34/100
#
# Epoch 34: val_iou_score did not improve from 0.87142
# 269/269 - 109s - loss: 0.1430 - iou_score: 0.8708 - val_loss: 0.1434 - val_iou_score: 0.8708 - 109s/epoch - 406ms/step
# Epoch 35/100
#
# Epoch 35: val_iou_score did not improve from 0.87142
# 269/269 - 111s - loss: 0.1382 - iou_score: 0.8737 - val_loss: 0.1556 - val_iou_score: 0.8592 - 111s/epoch - 414ms/step
# Epoch 36/100
#
# Epoch 36: val_iou_score did not improve from 0.87142
# 269/269 - 109s - loss: 0.1437 - iou_score: 0.8687 - val_loss: 0.1480 - val_iou_score: 0.8670 - 109s/epoch - 405ms/step
# Epoch 37/100
#
# Epoch 37: val_iou_score did not improve from 0.87142
# 269/269 - 111s - loss: 0.1433 - iou_score: 0.8705 - val_loss: 0.1419 - val_iou_score: 0.8707 - 111s/epoch - 413ms/step
# Epoch 38/100
#
# Epoch 38: val_iou_score did not improve from 0.87142
# 269/269 - 111s - loss: 0.1421 - iou_score: 0.8711 - val_loss: 0.1467 - val_iou_score: 0.8677 - 111s/epoch - 413ms/step
# Epoch 39/100
#
# Epoch 39: val_iou_score did not improve from 0.87142
# 269/269 - 109s - loss: 0.1388 - iou_score: 0.8731 - val_loss: 0.1648 - val_iou_score: 0.8509 - 109s/epoch - 405ms/step
# Epoch 40/100
#
# Epoch 40: val_iou_score improved from 0.87142 to 0.87972, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-40-0.8797unet_resnet50.hdf5
# 269/269 - 115s - loss: 0.1392 - iou_score: 0.8740 - val_loss: 0.1330 - val_iou_score: 0.8797 - 115s/epoch - 426ms/step
# Epoch 41/100
#
# Epoch 41: val_iou_score did not improve from 0.87972
# 269/269 - 111s - loss: 0.1397 - iou_score: 0.8731 - val_loss: 0.1463 - val_iou_score: 0.8666 - 111s/epoch - 413ms/step
# Epoch 42/100
#
# Epoch 42: val_iou_score did not improve from 0.87972
# 269/269 - 111s - loss: 0.1374 - iou_score: 0.8754 - val_loss: 0.1464 - val_iou_score: 0.8659 - 111s/epoch - 413ms/step
# Epoch 43/100
#
# Epoch 43: val_iou_score did not improve from 0.87972
# 269/269 - 111s - loss: 0.1422 - iou_score: 0.8710 - val_loss: 0.1576 - val_iou_score: 0.8592 - 111s/epoch - 413ms/step
# Epoch 44/100
#
# Epoch 44: val_iou_score did not improve from 0.87972
# 269/269 - 111s - loss: 0.1401 - iou_score: 0.8729 - val_loss: 0.1388 - val_iou_score: 0.8743 - 111s/epoch - 413ms/step
# Epoch 45/100
#
# Epoch 45: val_iou_score did not improve from 0.87972
# 269/269 - 108s - loss: 0.1320 - iou_score: 0.8806 - val_loss: 0.1494 - val_iou_score: 0.8655 - 108s/epoch - 401ms/step
# Epoch 46/100
#
# Epoch 46: val_iou_score did not improve from 0.87972
# 269/269 - 111s - loss: 0.1344 - iou_score: 0.8782 - val_loss: 0.1503 - val_iou_score: 0.8661 - 111s/epoch - 412ms/step
# Epoch 47/100
#
# Epoch 47: val_iou_score did not improve from 0.87972
# 269/269 - 108s - loss: 0.1386 - iou_score: 0.8745 - val_loss: 0.1382 - val_iou_score: 0.8751 - 108s/epoch - 402ms/step
# Epoch 48/100
#
# Epoch 48: val_iou_score did not improve from 0.87972
# 269/269 - 111s - loss: 0.1341 - iou_score: 0.8786 - val_loss: 0.1417 - val_iou_score: 0.8719 - 111s/epoch - 412ms/step
# Epoch 49/100
#
# Epoch 49: val_iou_score did not improve from 0.87972
# 269/269 - 111s - loss: 0.1315 - iou_score: 0.8811 - val_loss: 0.1471 - val_iou_score: 0.8663 - 111s/epoch - 412ms/step
# Epoch 50/100
#
# Epoch 50: val_iou_score did not improve from 0.87972
# 269/269 - 108s - loss: 0.1318 - iou_score: 0.8804 - val_loss: 0.1392 - val_iou_score: 0.8745 - 108s/epoch - 403ms/step
# Epoch 51/100
#
# Epoch 51: val_iou_score did not improve from 0.87972
# 269/269 - 108s - loss: 0.1324 - iou_score: 0.8797 - val_loss: 0.1413 - val_iou_score: 0.8718 - 108s/epoch - 401ms/step
# Epoch 52/100
#
# Epoch 52: val_iou_score did not improve from 0.87972
# 269/269 - 108s - loss: 0.1318 - iou_score: 0.8808 - val_loss: 0.1442 - val_iou_score: 0.8696 - 108s/epoch - 400ms/step
# Epoch 53/100
#
# Epoch 53: val_iou_score did not improve from 0.87972
# 269/269 - 108s - loss: 0.1318 - iou_score: 0.8806 - val_loss: 0.1376 - val_iou_score: 0.8762 - 108s/epoch - 403ms/step
# Epoch 54/100
#
# Epoch 54: val_iou_score did not improve from 0.87972
# 269/269 - 111s - loss: 0.1353 - iou_score: 0.8777 - val_loss: 0.1420 - val_iou_score: 0.8716 - 111s/epoch - 412ms/step
# Epoch 55/100
#
# Epoch 55: val_iou_score did not improve from 0.87972
# 269/269 - 111s - loss: 0.1299 - iou_score: 0.8814 - val_loss: 0.1350 - val_iou_score: 0.8770 - 111s/epoch - 412ms/step
# Epoch 56/100
#
# Epoch 56: val_iou_score did not improve from 0.87972
# 269/269 - 108s - loss: 0.1311 - iou_score: 0.8797 - val_loss: 0.1389 - val_iou_score: 0.8749 - 108s/epoch - 400ms/step
# Epoch 57/100
#
# Epoch 57: val_iou_score did not improve from 0.87972
# 269/269 - 111s - loss: 0.1316 - iou_score: 0.8809 - val_loss: 0.1390 - val_iou_score: 0.8749 - 111s/epoch - 412ms/step
# Epoch 58/100
#
# Epoch 58: val_iou_score improved from 0.87972 to 0.88143, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-58-0.8814unet_resnet50.hdf5
# 269/269 - 113s - loss: 0.1346 - iou_score: 0.8782 - val_loss: 0.1305 - val_iou_score: 0.8814 - 113s/epoch - 421ms/step
# Epoch 59/100
#
# Epoch 59: val_iou_score did not improve from 0.88143
# 269/269 - 111s - loss: 0.1319 - iou_score: 0.8806 - val_loss: 0.1462 - val_iou_score: 0.8679 - 111s/epoch - 412ms/step
# Epoch 60/100
#
# Epoch 60: val_iou_score did not improve from 0.88143
# 269/269 - 111s - loss: 0.1332 - iou_score: 0.8785 - val_loss: 0.1402 - val_iou_score: 0.8743 - 111s/epoch - 412ms/step
# Epoch 61/100
#
# Epoch 61: val_iou_score did not improve from 0.88143
# 269/269 - 108s - loss: 0.1340 - iou_score: 0.8787 - val_loss: 0.1713 - val_iou_score: 0.8451 - 108s/epoch - 403ms/step
# Epoch 62/100
#
# Epoch 62: val_iou_score did not improve from 0.88143
# 269/269 - 111s - loss: 0.1281 - iou_score: 0.8841 - val_loss: 0.1454 - val_iou_score: 0.8682 - 111s/epoch - 412ms/step
# Epoch 63/100
#
# Epoch 63: val_iou_score did not improve from 0.88143
# 269/269 - 111s - loss: 0.1320 - iou_score: 0.8801 - val_loss: 0.1393 - val_iou_score: 0.8742 - 111s/epoch - 412ms/step
# Epoch 64/100
#
# Epoch 64: val_iou_score did not improve from 0.88143
# 269/269 - 111s - loss: 0.1307 - iou_score: 0.8815 - val_loss: 0.1486 - val_iou_score: 0.8659 - 111s/epoch - 412ms/step
# Epoch 65/100
#
# Epoch 65: val_iou_score did not improve from 0.88143
# 269/269 - 111s - loss: 0.1289 - iou_score: 0.8831 - val_loss: 0.1317 - val_iou_score: 0.8802 - 111s/epoch - 412ms/step
# Epoch 66/100
#
# Epoch 66: val_iou_score did not improve from 0.88143
# 269/269 - 109s - loss: 0.1278 - iou_score: 0.8842 - val_loss: 0.1399 - val_iou_score: 0.8736 - 109s/epoch - 404ms/step
# Epoch 67/100
#
# Epoch 67: val_iou_score did not improve from 0.88143
# 269/269 - 111s - loss: 0.1272 - iou_score: 0.8843 - val_loss: 0.1365 - val_iou_score: 0.8771 - 111s/epoch - 412ms/step
# Epoch 68/100
#
# Epoch 68: val_iou_score did not improve from 0.88143
# 269/269 - 108s - loss: 0.1294 - iou_score: 0.8823 - val_loss: 0.1487 - val_iou_score: 0.8653 - 108s/epoch - 403ms/step
# Epoch 69/100
#
# Epoch 69: val_iou_score did not improve from 0.88143
# 269/269 - 108s - loss: 0.1254 - iou_score: 0.8856 - val_loss: 0.1549 - val_iou_score: 0.8616 - 108s/epoch - 402ms/step
# Epoch 70/100
#
# Epoch 70: val_iou_score improved from 0.88143 to 0.88443, saving model to /content/drive/My Drive/Colab Notebooks/model_checkpoints/model-70-0.8844unet_resnet50.hdf5
# 269/269 - 110s - loss: 0.1314 - iou_score: 0.8804 - val_loss: 0.1278 - val_iou_score: 0.8844 - 110s/epoch - 410ms/step
# Epoch 71/100
#
# Epoch 71: val_iou_score did not improve from 0.88443
# 269/269 - 109s - loss: 0.1259 - iou_score: 0.8861 - val_loss: 0.1362 - val_iou_score: 0.8771 - 109s/epoch - 404ms/step
# Epoch 72/100
#
# Epoch 72: val_iou_score did not improve from 0.88443
# 269/269 - 108s - loss: 0.1226 - iou_score: 0.8886 - val_loss: 0.1346 - val_iou_score: 0.8783 - 108s/epoch - 400ms/step
# Epoch 73/100
#
# Epoch 73: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1220 - iou_score: 0.8895 - val_loss: 0.1424 - val_iou_score: 0.8712 - 111s/epoch - 412ms/step
# Epoch 74/100
#
# Epoch 74: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1279 - iou_score: 0.8842 - val_loss: 0.1379 - val_iou_score: 0.8757 - 111s/epoch - 412ms/step
# Epoch 75/100
#
# Epoch 75: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1186 - iou_score: 0.8925 - val_loss: 0.1320 - val_iou_score: 0.8815 - 111s/epoch - 412ms/step
# Epoch 76/100
#
# Epoch 76: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1207 - iou_score: 0.8907 - val_loss: 0.1422 - val_iou_score: 0.8713 - 111s/epoch - 412ms/step
# Epoch 77/100
#
# Epoch 77: val_iou_score did not improve from 0.88443
# 269/269 - 108s - loss: 0.1240 - iou_score: 0.8872 - val_loss: 0.1390 - val_iou_score: 0.8751 - 108s/epoch - 401ms/step
# Epoch 78/100
#
# Epoch 78: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1218 - iou_score: 0.8898 - val_loss: 0.1416 - val_iou_score: 0.8725 - 111s/epoch - 412ms/step
# Epoch 79/100
#
# Epoch 79: val_iou_score did not improve from 0.88443
# 269/269 - 108s - loss: 0.1247 - iou_score: 0.8868 - val_loss: 0.1506 - val_iou_score: 0.8642 - 108s/epoch - 400ms/step
# Epoch 80/100
#
# Epoch 80: val_iou_score did not improve from 0.88443
# 269/269 - 108s - loss: 0.1219 - iou_score: 0.8897 - val_loss: 0.1447 - val_iou_score: 0.8691 - 108s/epoch - 400ms/step
# Epoch 81/100
#
# Epoch 81: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1210 - iou_score: 0.8892 - val_loss: 0.1328 - val_iou_score: 0.8796 - 111s/epoch - 411ms/step
# Epoch 82/100
#
# Epoch 82: val_iou_score did not improve from 0.88443
# 269/269 - 107s - loss: 0.1266 - iou_score: 0.8853 - val_loss: 0.1431 - val_iou_score: 0.8706 - 107s/epoch - 399ms/step
# Epoch 83/100
#
# Epoch 83: val_iou_score did not improve from 0.88443
# 269/269 - 109s - loss: 0.1173 - iou_score: 0.8933 - val_loss: 0.1353 - val_iou_score: 0.8778 - 109s/epoch - 404ms/step
# Epoch 84/100
#
# Epoch 84: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1219 - iou_score: 0.8897 - val_loss: 0.1371 - val_iou_score: 0.8772 - 111s/epoch - 411ms/step
# Epoch 85/100
#
# Epoch 85: val_iou_score did not improve from 0.88443
# 269/269 - 108s - loss: 0.1169 - iou_score: 0.8941 - val_loss: 0.1342 - val_iou_score: 0.8795 - 108s/epoch - 403ms/step
# Epoch 86/100
#
# Epoch 86: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1205 - iou_score: 0.8909 - val_loss: 0.1317 - val_iou_score: 0.8808 - 111s/epoch - 411ms/step
# Epoch 87/100
#
# Epoch 87: val_iou_score did not improve from 0.88443
# 269/269 - 108s - loss: 0.1207 - iou_score: 0.8907 - val_loss: 0.1375 - val_iou_score: 0.8764 - 108s/epoch - 402ms/step
# Epoch 88/100
#
# Epoch 88: val_iou_score did not improve from 0.88443
# 269/269 - 108s - loss: 0.1194 - iou_score: 0.8917 - val_loss: 0.1344 - val_iou_score: 0.8781 - 108s/epoch - 402ms/step
# Epoch 89/100
#
# Epoch 89: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1186 - iou_score: 0.8925 - val_loss: 0.1360 - val_iou_score: 0.8765 - 111s/epoch - 411ms/step
# Epoch 90/100
#
# Epoch 90: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1172 - iou_score: 0.8937 - val_loss: 0.1364 - val_iou_score: 0.8760 - 111s/epoch - 412ms/step
# Epoch 91/100
#
# Epoch 91: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1128 - iou_score: 0.8973 - val_loss: 0.1319 - val_iou_score: 0.8814 - 111s/epoch - 412ms/step
# Epoch 92/100
#
# Epoch 92: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1227 - iou_score: 0.8888 - val_loss: 0.1476 - val_iou_score: 0.8671 - 111s/epoch - 412ms/step
# Epoch 93/100
#
# Epoch 93: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1185 - iou_score: 0.8927 - val_loss: 0.1322 - val_iou_score: 0.8800 - 111s/epoch - 412ms/step
# Epoch 94/100
#
# Epoch 94: val_iou_score did not improve from 0.88443
# 269/269 - 108s - loss: 0.1176 - iou_score: 0.8937 - val_loss: 0.1314 - val_iou_score: 0.8823 - 108s/epoch - 400ms/step
# Epoch 95/100
#
# Epoch 95: val_iou_score did not improve from 0.88443
# 269/269 - 107s - loss: 0.1160 - iou_score: 0.8949 - val_loss: 0.1493 - val_iou_score: 0.8662 - 107s/epoch - 399ms/step
# Epoch 96/100
#
# Epoch 96: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1221 - iou_score: 0.8890 - val_loss: 0.1484 - val_iou_score: 0.8659 - 111s/epoch - 412ms/step
# Epoch 97/100
#
# Epoch 97: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1215 - iou_score: 0.8896 - val_loss: 0.1379 - val_iou_score: 0.8764 - 111s/epoch - 411ms/step
# Epoch 98/100
#
# Epoch 98: val_iou_score did not improve from 0.88443
# 269/269 - 108s - loss: 0.1182 - iou_score: 0.8930 - val_loss: 0.1320 - val_iou_score: 0.8804 - 108s/epoch - 402ms/step
# Epoch 99/100
#
# Epoch 99: val_iou_score did not improve from 0.88443
# 269/269 - 110s - loss: 0.1143 - iou_score: 0.8958 - val_loss: 0.1363 - val_iou_score: 0.8773 - 110s/epoch - 411ms/step
# Epoch 100/100
#
# Epoch 100: val_iou_score did not improve from 0.88443
# 269/269 - 111s - loss: 0.1133 - iou_score: 0.8974 - val_loss: 0.1439 - val_iou_score: 0.8700 - 111s/epoch - 411ms/step

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IoU')
plt.plot(epochs, val_acc, 'r', label='Validation IoU')
plt.title('Training and validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()
